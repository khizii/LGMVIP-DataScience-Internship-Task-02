# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings(action='ignore')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 50)

# %%
import chardet
with open('terrorism_data.csv', 'rb') as f:
      result= chardet.detect(f.read())

data = pd.read_csv('terrorism_data.csv', encoding = result['encoding'])

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data=data[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]

# %%
data.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
data.rename(columns={'iyear':'year', 'imonth':'month', 'iday':'day', 'country_txt':'country', 'region_txt':'region', 'provstate':'state',
       'city':'city', 'latitude':'lat', 'longitude':'long', 'location':'location', 'summary':'summary',
       'attacktype1_txt':'attack type', 'targtype1_txt':'target type', 'gname':'group', 'motive':'motive', 'weaptype1_txt':'weapon used',
       'nkill':'kill', 'nwound':'wound', 'addnotes':'add notes'},inplace=True)

# %%
data.head()
# Out:
#    year  month  day             country                       region    state  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             city        lat        long location summary  \
# 0  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1    Mexico city  19.371887  -99.086624      NaN     NaN
# 2        Unknown  15.478598  120.599741      NaN     NaN
# 3         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       attack type                  target type  \
# 0                   Assassination  Private Citizens & Property
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   year         181691 non-null  int64
#  1   month        181691 non-null  int64
#  2   day          181691 non-null  int64
#  3   country      181691 non-null  object
#  4   region       181691 non-null  object
#  5   state        181270 non-null  object
#  6   city         181257 non-null  object
#  7   lat          177135 non-null  float64
#  8   long         177134 non-null  float64
#  9   location     55495 non-null   object
#  10  summary      115562 non-null  object
#  11  attack type  181691 non-null  object
#  12  target type  181691 non-null  object
#  13  group        181691 non-null  object
#  14  motive       50561 non-null   object
#  15  weapon used  181691 non-null  object
#  16  kill         171378 non-null  float64
#  17  wound        165380 non-null  float64
# ...

# %%
for col in data.columns:
    data[col] = data[col].fillna(0)

# %%
data.isnull().sum()
# Out:
# year           0
# month          0
# day            0
# country        0
# region         0
# state          0
# city           0
# lat            0
# long           0
# location       0
# summary        0
# attack type    0
# target type    0
# group          0
# motive         0
# weapon used    0
# kill           0
# wound          0
# add notes      0
# dtype: int64

# %%
attack_df = data['year'].value_counts().sort_index().to_frame().reset_index()
attack_df = attack_df.rename(columns={'year':'attacks','index':'year'})
attack_df
# Out:
#     year  attacks
# 0   1970      651
# 1   1971      471
# 2   1972      568
# 3   1973      473
# 4   1974      581
# 5   1975      740
# 6   1976      923
# 7   1977     1319
# 8   1978     1526
# 9   1979     2662
# 10  1980     2662
# 11  1981     2586
# 12  1982     2544
# 13  1983     2870
# 14  1984     3495
# 15  1985     2915
# 16  1986     2860
# 17  1987     3183
# 18  1988     3721
# 19  1989     4324
# 20  1990     3887
# 21  1991     4683
# 22  1992     5071
# 23  1994     3456
# 24  1995     3081
# 25  1996     3058
# 26  1997     3197
# 27  1998      934
# 28  1999     1395
# 29  2000     1814
# 30  2001     1906
# 31  2002     1333
# 32  2003     1278
# 33  2004     1166
# 34  2005     2017
# 35  2006     2758
# 36  2007     3242
# 37  2008     4805
# 38  2009     4721
# 39  2010     4826
# 40  2011     5076
# 41  2012     8522
# 42  2013    12036
# 43  2014    16903
# 44  2015    14965
# 45  2016    13587
# 46  2017    10900

# %%
plt.figure(figsize=(25,15))
sns.barplot(x = 'year', y='attacks',data=attack_df)
# Out:
# <Axes: xlabel='year', ylabel='attacks'>

# %%
df_group = data[['country','state','city','kill','group']]
df_group.head()
# Out:
#               country    state           city  kill  \
# 0  Dominican Republic        0  Santo Domingo   1.0
# 1              Mexico  Federal    Mexico city   0.0
# 2         Philippines   Tarlac        Unknown   1.0
# 3              Greece   Attica         Athens   0.0
# 4               Japan  Fukouka        Fukouka   0.0
#
#                                 group
# 0                              MANO-D
# 1  23rd of September Communist League
# 2                             Unknown
# 3                             Unknown
# 4                             Unknown

# %%
top15_country = df_group.groupby('country').sum().sort_values('kill',ascending=False).head(15)
top15_country
# Out:
#                 kill
# country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0
# Algeria      11066.0
# Nicaragua    10598.0
# Somalia      10273.0
# Philippines   9559.0
# Yemen         8776.0

# %%
top15_country.reset_index(inplace=True)
plt.figure(figsize=(20, 15))
plot = sns.barplot(x='country', y='kill', data=top15_country)

# %%
top15_state = df_group.groupby('state').sum().sort_values('kill',ascending=False).head(15)
top15_state
# Out:
#                                         kill
# state
# Baghdad                              21215.0
# Unknown                              15476.0
# Nineveh                              15185.0
# Borno                                12063.0
# Al Anbar                             12009.0
# Saladin                              10673.0
# Diyala                                7779.0
# Eastern                               6323.0
# Northern                              5955.0
# Punjab                                5452.0
# Federally Administered Tribal Areas   5213.0
# Helmand                               4935.0
# Sindh                                 4402.0
# Balochistan                           4263.0
# Khyber Pakhtunkhwa                    4226.0

# %%
top15_state.reset_index(inplace=True)
plt.figure(figsize=(20, 15))
plot = sns.barplot(x='state', y='kill', data=top15_state)

# %%
top15_group = df_group.groupby('group').sum().sort_values('kill',ascending=False).head(15)
top15_group
# Out:
#                                                       kill
# group
# Unknown                                           112367.0
# Islamic State of Iraq and the Levant (ISIL)        38923.0
# Taliban                                            29410.0
# Boko Haram                                         20328.0
# Shining Path (SL)                                  11601.0
# Liberation Tigers of Tamil Eelam (LTTE)            10989.0
# Al-Shabaab                                          9330.0
# Farabundo Marti National Liberation Front (FMLN)    8065.0
# Nicaraguan Democratic Force (FDN)                   6662.0
# Tehrik-i-Taliban Pakistan (TTP)                     6042.0
# Revolutionary Armed Forces of Colombia (FARC)       5661.0
# Kurdistan Workers' Party (PKK)                      4955.0
# New People's Army (NPA)                             4386.0
# Al-Qaida in Iraq                                    4381.0
# Hutu extremists                                     4102.0

# %%
top15_group.reset_index(inplace=True)
plt.figure(figsize=(20, 15))
plot = sns.barplot(y='group', x='kill', data=top15_group)
